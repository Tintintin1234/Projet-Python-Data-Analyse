# %% [markdown]
# # Projet Python (BITAR Aref & BERTHAULT Quentin)
#
# Données choisies : "ObesityDataSet_raw_and_data_sinthetic.csv"
# ## Etudes de l'obésité sur une population de 2111 personnes

# %% [markdown]
# # I) Importation et observation des données
# ## 1) Le format des données

# %%
#Importation des bibliothèques utiles

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#On importe les données
data = pd.read_csv("ObesityDataSet_raw_and_data_sinthetic.csv")

# %%
#On regarde la forme des données (nb de collones et de lignes)
print(data.copy().shape)
dc = data.copy()
# Out:
# (2111, 17)

# %%
#On imprime une partie des données pour voir à quoi elles ressemblent
dh = data.head()
print(dh)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %% [markdown]
# #### On renomme les colonnes ayant des noms peu compréhensibles.

# %%
data.columns = ['Gender', 'Age', 'Height', 'Weight', 'family history with overweight',
       'Frequent consumption of high caloric food', 'Frequency of consumption of vegetables', 'Number of main meals', 'Consumption of food between meals', 'Smoke', 'Consumption of water daily', 'Calories consumption monitoring', 'Physical activity frequency', 'Time using technology devices',
       'Consumption of alcohol', 'Transportation used', 'Obesity']
print(data.columns)
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family history with overweight',
#        'Frequent consumption of high caloric food',
#        'Frequency of consumption of vegetables', 'Number of main meals',
#        'Consumption of food between meals', 'Smoke',
#        'Consumption of water daily', 'Calories consumption monitoring',
#        'Physical activity frequency', 'Time using technology devices',
#        'Consumption of alcohol', 'Transportation used', 'Obesity'],
#       dtype='object')

# %%
#On imprime toutes les données
data.copy()
# Out:
#       Gender        Age    Height      Weight family history with overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %% [markdown]
# #### On cherche à savoir si certaines cases ne sont pas remplies par des NA ou null

# %%
print("Numbers of NA by columns : \n")
data.isna().sum()
# Out:
# Numbers of NA by columns :
# Gender                                       0
# Age                                          0
# Height                                       0
# Weight                                       0
# family history with overweight               0
# Frequent consumption of high caloric food    0
# Frequency of consumption of vegetables       0
# Number of main meals                         0
# Consumption of food between meals            0
# Smoke                                        0
# Consumption of water daily                   0
# Calories consumption monitoring              0
# Physical activity frequency                  0
# Time using technology devices                0
# Consumption of alcohol                       0
# Transportation used                          0
# Obesity                                      0
# dtype: int64

# %%
print("Numbers of null by columns : \n")
data.isna().sum()
# Out:
# Numbers of null by columns :
# Gender                                       0
# Age                                          0
# Height                                       0
# Weight                                       0
# family history with overweight               0
# Frequent consumption of high caloric food    0
# Frequency of consumption of vegetables       0
# Number of main meals                         0
# Consumption of food between meals            0
# Smoke                                        0
# Consumption of water daily                   0
# Calories consumption monitoring              0
# Physical activity frequency                  0
# Time using technology devices                0
# Consumption of alcohol                       0
# Transportation used                          0
# Obesity                                      0
# dtype: int64

# %% [markdown]
# Il n'y a pas 1 seul null ou NA dans toutes les données.
# #### On cherche à différencier les différents types de données.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Gender                                     2111 non-null   object
#  1   Age                                        2111 non-null   float64
#  2   Height                                     2111 non-null   float64
#  3   Weight                                     2111 non-null   float64
#  4   family history with overweight             2111 non-null   object
#  5   Frequent consumption of high caloric food  2111 non-null   object
#  6   Frequency of consumption of vegetables     2111 non-null   float64
#  7   Number of main meals                       2111 non-null   float64
#  8   Consumption of food between meals          2111 non-null   object
#  9   Smoke                                      2111 non-null   object
# ...

# %%
#On regarde la forme des données (si ce sont des booléens, string ou int etc...)
print(data.copy().dtypes.value_counts())
print(data.copy().dtypes.value_counts().plot.pie())
print("")
#On ecrit les données si ce sont des floats
print("Les données ci-dessous sont sous forme de float64 (données quantitatives) :")
print("")
for col in data.select_dtypes('float64'):
    print(col)

#On ecrit les données si ce sont des strings ainsi que les résultats possibles de chaque données
print("")
print("les données ci-dessous sont sous forme de string (données qualitatives ou binaires) :")
print("")
for col in data.select_dtypes('object'):
    print(f'{col:-<40} {data[col].unique()}')
# Out:
# object     9
# float64    8
# dtype: int64
# AxesSubplot(0.260833,0.125;0.503333x0.755)
#
# Les données ci-dessous sont sous forme de float64 (données quantitatives) :
#
# Age
# Height
# Weight
# Frequency of consumption of vegetables
# Number of main meals
# Consumption of water daily
# Physical activity frequency
# Time using technology devices
#
# les données ci-dessous sont sous forme de string (données qualitatives ou binaires) :
#
# Gender---------------------------------- ['Female' 'Male']
# family history with overweight---------- ['yes' 'no']
# Frequent consumption of high caloric food ['no' 'yes']
# Consumption of food between meals------- ['Sometimes' 'Frequently' 'Always' 'no']
# Smoke----------------------------------- ['no' 'yes']
# Calories consumption monitoring--------- ['no' 'yes']
# Consumption of alcohol------------------ ['no' 'Sometimes' 'Frequently' 'Always']
# ...

# %% [markdown]
# #### Il y a 8 colonnes de floatant et 9 colonnes d'objets
# On a donc 2110 lignes de données composées de 17 colonnes. Sur ces colonnes, 9 sont des objets et 8 sont des float64.
# Il n'y a aucune donnée manquante, toutes les cases sont remplies.
# Le nom des colonnes à été modifié pour une meilleure lisibilité
#
# ## 2) Données de format float64
#
# #### On regarde d'abord les données sous forme de floatant

# %% [markdown]
# On imprime ces données

# %%
data.select_dtypes('double')
# Out:
#             Age    Height      Weight  Frequency of consumption of vegetables  \
# 0     21.000000  1.620000   64.000000                                     2.0
# 1     21.000000  1.520000   56.000000                                     3.0
# 2     23.000000  1.800000   77.000000                                     2.0
# 3     27.000000  1.800000   87.000000                                     3.0
# 4     22.000000  1.780000   89.800000                                     2.0
# ...         ...       ...         ...                                     ...
# 2106  20.976842  1.710730  131.408528                                     3.0
# 2107  21.982942  1.748584  133.742943                                     3.0
# 2108  22.524036  1.752206  133.689352                                     3.0
# 2109  24.361936  1.739450  133.346641                                     3.0
# 2110  23.664709  1.738836  133.472641                                     3.0
#
# ...

# %%
#On regarde à quoi ressemble les différents quartiles, moyennes et autres données statistiques quand c'est possible d'en avoir
data.describe()
# Out:
#                Age       Height       Weight  \
# count  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058
# std       6.345968     0.093305    26.191172
# min      14.000000     1.450000    39.000000
# 25%      19.947192     1.630000    65.473343
# 50%      22.777890     1.700499    83.000000
# 75%      26.000000     1.768464   107.430682
# max      61.000000     1.980000   173.000000
#
#        Frequency of consumption of vegetables  Number of main meals  \
# count                             2111.000000           2111.000000
# mean                                 2.419043              2.685628
# std                                  0.533927              0.778039
# min                                  1.000000              1.000000
# 25%                                  2.000000              2.658738
# 50%                                  2.385502              3.000000
# 75%                                  3.000000              3.000000
# ...

# %% [markdown]
# #### On affiche sur un diagramme les différentes données et les tendances associées

# %%
#Diagramme des données quantitatives
for i in data.select_dtypes('double'):
    plt.figure()
    ax=sns.displot(data[i], kind="hist", kde=True,  height=6, color='r')

# %% [markdown]
# ### 3) Données en forme de objet

# %% [markdown]
# Voici le format que peuvent prendre les données de type objet:

# %%
for i in data.select_dtypes('object'):
    print(f'{i: <45} {data[i].unique()}')
    print ("")
# Out:
# Gender                                        ['Female' 'Male']
#
# family history with overweight                ['yes' 'no']
#
# Frequent consumption of high caloric food     ['no' 'yes']
#
# Consumption of food between meals             ['Sometimes' 'Frequently' 'Always' 'no']
#
# Smoke                                         ['no' 'yes']
#
# Calories consumption monitoring               ['no' 'yes']
#
# Consumption of alcohol                        ['no' 'Sometimes' 'Frequently' 'Always']
#
# Transportation used                           ['Public_Transportation' 'Walking' 'Automobile' 'Motorbike' 'Bike']
#
# Obesity                                       ['Normal_Weight' 'Overweight_Level_I' 'Overweight_Level_II'
#  'Obesity_Type_I' 'Insufficient_Weight' 'Obesity_Type_II'
#  'Obesity_Type_III']

# %%
#Pie Chart des données binaires et qualitatives
for col in data.select_dtypes('object'):
    plt.figure()
    data[col].value_counts().plot.pie()

# %% [markdown]
# ### 4) Problématique

# %% [markdown]
# #### Ici, on va chercher à savoir la chose suivante: dans quelle mesure peut-on prédire le niveau d'obésité d'une personne à partir de ses habitudes et de ses données physique?

# %% [markdown]
# On sait que le niveau d'obésité est fortement lié à la masse corporel et à la taille d'une personne.

# %%
#On classe les données
floatant =["Age","Height","Weight","FCVC","NCP","CH2O","FAF","TUE"]
objets =["gender", 'family history with overweight','Frequent consumption of high caloric food', 'Frequency of consumption of vegetables', 'Consumption of food between meals', 'Smoke',
       'Consumption of alcohol', 'Transportation used', 'Obesity']
#On regarde les pourcentages et le nombre de personne pour la collonne "NOeyesdad"
print("Valeurs en pourcentage :")
print("")
print(data.copy()['Obesity'].value_counts(normalize=True))
print("")
print("Valeurs numériques :")
print("")
print(data.copy()['Obesity'].value_counts())
print("")
print("Diagramme en camembert des données d'obésité")
print(data['Obesity'].value_counts().plot.pie())
# Out:
# Valeurs en pourcentage :
#
# Obesity_Type_I         0.166272
# Obesity_Type_III       0.153482
# Obesity_Type_II        0.140692
# Overweight_Level_I     0.137376
# Overweight_Level_II    0.137376
# Normal_Weight          0.135955
# Insufficient_Weight    0.128849
# Name: Obesity, dtype: float64
#
# Valeurs numériques :
#
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: Obesity, dtype: int64
#
# Diagramme en camembert des données d'obésité
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %% [markdown]
# La répartition du niveau d'obésité est relativement homogène, toutes les catégories représentent entre 12,8 et 16,7% de la population étudiée. Toutefois les personnes obèses (Obesity_typeI , II et III) représentent près de 46% des personnes .

# %%
homme=dc[dc['Gender']=='Male']
femme=dc[dc['Gender']=='Female']
for i in dc.select_dtypes('object'):    
    plt.figure(figsize=(15,8))
    plt.title(i)    
    ax = sns.barplot(x = dc[i].value_counts().index.to_list(), y = dc[i].value_counts().to_list())

# %% [markdown]
# Toutefois les données ne sont pas forcément les mêmes selon si l'on parle d'homme ou de femme.

# %% [markdown]
# ### 5) Focus sur la relation entre masse et taille

# %%
ax1 = homme.plot.scatter(x='Height',y='Weight', color='b')
sns.regplot(homme.Height, homme.Weight, color='r')
plt.title("Homme Weight/Height")

ax2= femme.plot.scatter(x='Height',y='Weight')
sns.regplot(femme.Height, femme.Weight, color='r')
plt.title("Femme Weight/Height")

ax3= sns.lmplot(x="Height", y="Weight", hue="Gender", data=dc)
ax3.set_axis_labels("Height", "Weight")
plt.title("Homme and Femme Weight/Height")
# Out:
# C:\Users\Aref BITAR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Aref BITAR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Homme and Femme Weight/Height')

# %%
sns.set(style="darkgrid")

fig = plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
sns.boxplot(x='Gender', y='Height', palette="Blues", data=data)
plt.subplot(1, 2, 2)
sns.boxplot(x='Gender', y='Weight',palette="Blues", data=data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Weight'>

# %% [markdown]
# #### On remarque qu'en moyenne les hommes sont plus lourd mais aussi plus grand que les femmes.

# %% [markdown]
# ## II) Étude de la corrélation des différentes données avec le niveau d'obésité

# %% [markdown]
# On sait que la masse est une des données les plus importantes.
# On calcule la corrélation de la masse par rapport aux autres données:

# %%
data.corr()["Weight"]
# Out:
# Age                                       0.202560
# Height                                    0.463136
# Weight                                    1.000000
# Frequency of consumption of vegetables    0.216125
# Number of main meals                      0.107469
# Consumption of water daily                0.200575
# Physical activity frequency              -0.051436
# Time using technology devices            -0.071561
# Name: Weight, dtype: float64

# %% [markdown]
# On cherche à connaitre la correlation entre NObeyesdad (le niveau d'obésité) et les variables qualitatives :

# %%
data = pd.read_csv("ObesityDataSet_raw_and_data_sinthetic.csv")
dc=data.copy()
homme=dc[dc['Gender']=='Male']
femme=dc[dc['Gender']=='Female']
dc_obesityI = dc[dc['NObeyesdad']== 'Obesity_Type_I']
dc_obesityII = dc[dc['NObeyesdad']== 'Obesity_Type_II']
dc_obesityIII = dc[dc['NObeyesdad']== 'Obesity_Type_III']
dc_insuff = dc[dc['NObeyesdad']== 'Insufficient_Weight']
dc_normal = dc[dc['NObeyesdad']== 'Normal_Weight']
dc_overI = dc[dc['NObeyesdad']== 'Overweight_Level_I']
dc_overII = dc[dc['NObeyesdad']== 'Overweight_Level_II']

# %% [markdown]
# #### Att: la fonction utilisée pour tracer les graphiques semble être prévu pour ne plus être présente dans les prochaines versions et affiche un message d'erreur l'indiquant à chaque fois qu'il est utilisé

# %%
for col in floatant:
    plt.figure()
    sns.distplot(dc_obesityI[col], label = 'obesityI')
    sns.distplot(dc_obesityII[col], label = 'obesityII')
    sns.distplot(dc_obesityIII[col], label = 'obesityIII')
    sns.distplot(dc_insuff[col], label = 'insuff')
    sns.distplot(dc_normal[col], label = 'normal')
    sns.distplot(dc_overI[col], label = 'overI')
    sns.distplot(dc_overII[col], label = 'overII')
    plt.legend()
# Out:
# C:\Users\Aref BITAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Aref BITAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Meme chose cette fois-ci mais avec les variables quantitatives :

# %%
objets= ["family_history_with_overweight","FAVC","CAEC","SMOKE","SCC","CALC","MTRANS",'Gender']
for col in objets:
    plt.figure()
    sns.heatmap(pd.crosstab(data['NObeyesdad'],dc[col]),annot = True,fmt="d",center= 300)

# %% [markdown]
# ### On trace la matrice de corrélation

# %%
#matrice de corrélation:
sns.heatmap(data.corr(), center = 1, annot= True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# On remarque que la donnée avec laquelle, le niveau d'obesité est la plus corrélée est la masse corporelle "Weight"

# %% [markdown]
# ## III) Création d'un modèle

# %% [markdown]
# ### 1) Préparation

# %% [markdown]
# On importe les fonctions nécessaires, et créons un training et test set

# %%
from sklearn.model_selection import train_test_split
#On créé 2 sets de données à partir de notre base de donnée initiale
def split(df):
    trainset, testset = train_test_split(df, test_size=0.3, random_state=0)
    return trainset,testset

# %% [markdown]
# #### On va remplacer les données qualitatives en données quantitatives pour mieux les intégrer dans le modèle
# On créé un dictionnaire contenant les mots à remplacer et l'int64 associé avec lequel on le remplace puis on créé la fonction change qui réalise l'opération souhaité

# %%
données = {'no':1,
              'yes':1,
              'Female':0,
              'Male':1,
              'Sometimes':1,
              'Frequently':2,
              'Always':3,
              'Automobile':1,
              'Motorbike':2,
              'Bike':3, 
              'Public_Transportation':4,
              'Walking':5, 
              'Insufficient_Weight':0,
              'Normal_Weight':1 ,
              'Overweight_Level_I':2 ,
              'Overweight_Level_II':3,
              'Obesity_Type_I':4,            
              'Obesity_Type_II':5,
              'Obesity_Type_III':6
           }

def change(df):
    for col in df.select_dtypes('object').columns:
        df.loc[:,col] = df[col].map(données)
    
    return df

# %% [markdown]
# On applique le changement et on vérifie qu'elle s'est bien réalisé

# %%
change(dc)
print(dc)
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          0  21.000000  1.620000   64.000000                               1
# 1          0  21.000000  1.520000   56.000000                               1
# 2          1  23.000000  1.800000   77.000000                               1
# 3          1  27.000000  1.800000   87.000000                               1
# 4          1  22.000000  1.780000   89.800000                               1
# ...      ...        ...       ...         ...                             ...
# 2106       0  20.976842  1.710730  131.408528                               1
# 2107       0  21.982942  1.748584  133.742943                               1
# 2108       0  22.524036  1.752206  133.689352                               1
# 2109       0  24.361936  1.739450  133.346641                               1
# 2110       0  23.664709  1.738836  133.472641                               1
#
# ...

# %% [markdown]
# On créé une fonction pour enlever la colonne que l'on veut

# %%
def preprocessing(df,name):
    df = change(df)
    X = df.drop(name,axis = 1)
    Y = df[name]
    
    return X, Y

# %% [markdown]
# On créé les training et test set.

# %%
trainset, testset = split (dc)
X_test, Y_test = preprocessing(testset,'NObeyesdad')
X_train, Y_train = preprocessing(trainset,'NObeyesdad')

# %% [markdown]
# On va utiliser différents modèles et les comparer.

# %% [markdown]
# ### 2) Choix des modèles

# %% [markdown]
# On séléctionne plusieures modèles adapté à la situation et aux données

# %% [markdown]
# On importe les fonctions que l'on va utiliser depuis sklearn

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score, confusion_matrix, classification_report,make_scorer
from sklearn.model_selection import learning_curve
adaboost_model = AdaBoostClassifier(random_state=0)
model_decisiontree= DecisionTreeClassifier(random_state=0)
knn_model = KNeighborsClassifier()
boosting_model = GradientBoostingClassifier()

# %% [markdown]
# On va alors tester tous ces modèles et mesurer leur précision sur le même train et test set.
# La fonction precision va servir à mesurer la précision des modèles

# %%
def precision(model):
    model.fit(X_train, Y_train)
    ypred = model.predict(X_test)
    model_acc = accuracy_score(Y_test, ypred)
    print(confusion_matrix(Y_test, ypred)) 
    print(classification_report(Y_test, ypred))
    print('Précision : ' + str(model_acc))
    
print("Decision Tree")
precision(model_decisiontree)
print("")
print("Adaboost model")
precision(adaboost_model)
print("")
print("K plus proches voisins")
precision(knn_model)
print("")
print("Model Boosting")
precision(boosting_model)
# Out:
# Decision Tree
# [[ 87   3   0   0   0   0   0]
#  [  7  75   4   1   0   0   0]
#  [  0   7  69   5   0   0   0]
#  [  0   0   4  74   4   0   0]
#  [  0   0   0   1 100   2   0]
#  [  0   0   0   0   1  89   0]
#  [  0   0   0   0   0   0 101]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95        90
#            1       0.88      0.86      0.87        87
#            2       0.90      0.85      0.87        81
#            3       0.91      0.90      0.91        82
#            4       0.95      0.97      0.96       103
#            5       0.98      0.99      0.98        90
#            6       1.00      1.00      1.00       101
#
#     accuracy                           0.94       634
#    macro avg       0.94      0.93      0.93       634
# weighted avg       0.94      0.94      0.94       634
#
# Précision : 0.9384858044164038
#
# Adaboost model
# [[  1  89   0   0   0   0   0]
#  [  0  67  20   0   0   0   0]
# ...

# %% [markdown]
# Le modèle boosting est le plus précis (95.8%), suivit du modèle d'arbre de décision (93,8%). Le modèle des K plus proches voisins est lui aussi relativement précis mais moins que le précedent (86.9%) contrairement au modèle adaboost, qui lui n'est pas précis du tout (29,2%).
# Les performances du model adaboosting étant vraiment trop faible, on le passera pour la suite.
# On va regarder l'importance de chaque variable selon les méthodes decision tree et boosting model (la fonction fearure_importance ne semble pas exister pour le modèle knn)

# %%
print("1ere figure : Decision Tree")
pd.DataFrame(model_decisiontree.feature_importances_, index= X_train.columns).plot.bar(figsize=(12, 10))
print("2eme figure : Boosting Model")
pd.DataFrame(boosting_model.feature_importances_, index= X_train.columns).plot.bar(figsize=(12, 10))
# Out:
# 1ere figure : Decision Tree
# 2eme figure : Boosting Model
# <AxesSubplot:>

# %% [markdown]
# ## IV) Amélioration du modèle

# %% [markdown]
# Une idée pour améliorer le modèle serait d'ajouter une donnée significative ou autre qui a une bonne relation avec le résultat à prédir.
# En effet, un indicateur connu dans la mesure de l'obésité qui est l'IMC, c'est même un indicateur pour donner grossièrement le niveau d'obésité (car ne tenant pas compte de la masse musculaire, osseuse ou le niveau d'hydratation par exemple), mais qui a le mérite de se calculer assez rapidement et
# Et qui est: IMC = Masse/taille²
# On réutilise un data set non modifié comme l'a été le précédent:

# %%
dcnew = data.copy()
IMC = dcnew["Weight"]/((dcnew["Height"])**2)
dcnew.insert(loc = 2, column='IMC', value=IMC)

# %%
dcnew_obesityI = dcnew[dcnew['NObeyesdad']== 'Obesity_Type_I']
dcnew_obesityII = dcnew[dcnew['NObeyesdad']== 'Obesity_Type_II']
dcnew_obesityIII = dcnew[dcnew['NObeyesdad']== 'Obesity_Type_III']
dcnew_insuff = dcnew[dcnew['NObeyesdad']== 'Insufficient_Weight']
dcnew_normal = dcnew[dcnew['NObeyesdad']== 'Normal_Weight']
dcnew_overI = dcnew[dcnew['NObeyesdad']== 'Overweight_Level_I']
dcnew_overII = dcnew[dcnew['NObeyesdad']== 'Overweight_Level_II']

# %% [markdown]
# On trace le niveau d'obesité en fonction de l'IMC associé

# %%
plt.figure()
sns.distplot(dcnew_obesityI['IMC'], label = 'obesityI')
sns.distplot(dcnew_obesityII['IMC'], label = 'obesityII')
sns.distplot(dcnew_obesityIII['IMC'], label = 'obesityIII')
sns.distplot(dcnew_insuff['IMC'], label = 'insuff')
sns.distplot(dcnew_normal['IMC'], label = 'normal')
sns.distplot(dcnew_overI['IMC'], label = 'overI')
sns.distplot(dcnew_overII['IMC'], label = 'overII')
plt.title("Densité du type d'obésité par rapport à l'IMC associé")
plt.legend()
# Out:
# C:\Users\Aref BITAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Aref BITAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### On remarque que les différents niveau d'obésité sont assez bien séparé et forment des "régions distinctes"
# L'utilisation de l'IMC semble bien être pertinent. Testons les modèles précédents sur ce nouveau set de donnée

# %%
#On refait des trainings et datasets:
dcnew = change(dcnew)
X = dcnew.drop('NObeyesdad',axis = 1)
Y = dcnew['NObeyesdad']
trainset, testset = split (dcnew)
X_test, Y_test = preprocessing(testset,'NObeyesdad')
X_train, Y_train = preprocessing(trainset, 'NObeyesdad')
print(dcnew)
# Out:
#       Gender        Age        IMC    Height      Weight  \
# 0          0  21.000000  24.386526  1.620000   64.000000
# 1          0  21.000000  24.238227  1.520000   56.000000
# 2          1  23.000000  23.765432  1.800000   77.000000
# 3          1  27.000000  26.851852  1.800000   87.000000
# 4          1  22.000000  28.342381  1.780000   89.800000
# ...      ...        ...        ...       ...         ...
# 2106       0  20.976842  44.901475  1.710730  131.408528
# 2107       0  21.982942  43.741923  1.748584  133.742943
# 2108       0  22.524036  43.543817  1.752206  133.689352
# 2109       0  24.361936  44.071535  1.739450  133.346641
# 2110       0  23.664709  44.144338  1.738836  133.472641
#
#       family_history_with_overweight  FAVC  FCVC  NCP  CAEC  SMOKE      CH2O  \
# 0                                  1     1   2.0  3.0     1      1  2.000000
# 1                                  1     1   3.0  3.0     1      1  3.000000
# ...

# %%
print("Decision Tree")
precision(model_decisiontree)
print("")
print("K plus proches voisins")
precision(knn_model)
print("")
print("Model Boosting")
precision(boosting_model)
# Out:
# Decision Tree
# [[ 88   2   0   0   0   0   0]
#  [  1  86   0   0   0   0   0]
#  [  0   3  77   1   0   0   0]
#  [  0   0   3  78   1   0   0]
#  [  0   0   0   0 103   0   0]
#  [  0   0   0   0   1  89   0]
#  [  0   0   0   0   0   0 101]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98        90
#            1       0.95      0.99      0.97        87
#            2       0.96      0.95      0.96        81
#            3       0.99      0.95      0.97        82
#            4       0.98      1.00      0.99       103
#            5       1.00      0.99      0.99        90
#            6       1.00      1.00      1.00       101
#
#     accuracy                           0.98       634
#    macro avg       0.98      0.98      0.98       634
# weighted avg       0.98      0.98      0.98       634
#
# Précision : 0.9810725552050473
#
# K plus proches voisins
# [[ 89   1   0   0   0   0   0]
#  [ 11  61  14   1   0   0   0]
# ...

# %% [markdown]
# Cette fois-ci le modèle d'arbre de décision, possédant une bien meilleure précision que précédemment (de 5 points quasiment) est le plus précis des modèles avec 0.4 points de plus que le modèle boosting. Le modèle des K plus proches voisins est définitivement le moins précis des 3 malgré sa précision saluable (92.9% soit près de 5 points de moins que l'arbre de décision).
#
# Dans tous les cas, l'utilisation de l'IMC a grandement amélioré la précision des modèles.
